# %%
import pandas as pd
import os
from splink import Linker, SettingsCreator, block_on, DuckDBAPI
import splink.comparison_library as cl
from splink.exploratory import completeness_chart, profile_columns

#Loading the sample dataset 
file_path = '../data/febrl_sample_dataset.csv'
df = pd.read_csv(file_path)
df.head()
# Out:
#   given_name     surname  street_number          address_1  address_2  \
# 0        NaN      waller            6.0   tullaroop street   willaroo
# 1    lachlan       berry           69.0      giblin street  killarney
# 2     deakin  sondergeld           48.0  goldfinch circuit    kooltuo
# 3      kayla  harrington            NaN     maltby circuit    coaling
# 4       luke      purdon           23.0       ramsay place     mirani
#
#        suburb  postcode state  date_of_birth  unique_id
# 0    st james      4011    wa     19081209.0    6988048
# 1     bittern      4814   qld     19990219.0    7364009
# 2  canterbury      2776   vic     19600210.0    2635962
# 3    coolaroo      3465   nsw     19150612.0    9004242
# 4     garbutt      2260   vic     19831024.0    8099933

# %%
# checking the completness of each column
db_api = DuckDBAPI()
completeness_chart(df, db_api=db_api)
# Out:
# alt.LayerChart(...)

# %%
#runing exploratory analysis for sample dataset 
profile_columns(df, db_api=DuckDBAPI(), top_n=10, bottom_n=5)
# Out:
# alt.VConcatChart(...)

# %%
#choosing blocking rules to optimise runtime
from splink.blocking_analysis import (
    cumulative_comparisons_to_be_scored_from_blocking_rules_chart,
)

blocking_rules_for_analysis = [
    block_on("substr(given_name, 1,1)", "surname"),
    block_on("surname"),
    block_on("postcode"),
    "l.given_name = r.given_name and levenshtein(l.surname, r.surname) < 2",
]


cumulative_comparisons_to_be_scored_from_blocking_rules_chart(
    table_or_tables=df,
    blocking_rules=blocking_rules_for_analysis,
    db_api=db_api,
    link_type="dedupe_only",
)
# Out:
# alt.Chart(...)

# %%
# Configure Splink settings with choosen blocking rule
settings = SettingsCreator(
    link_type="dedupe_only",  # Deduplication mode
    blocking_rules_to_generate_predictions=[
        block_on("surname"),  
        block_on("postcode"),
        block_on("given_name")  
    ],
    comparisons=[
        cl.NameComparison("given_name").configure(term_frequency_adjustments=True),
        cl.NameComparison("surname").configure(term_frequency_adjustments=True),
        cl.ExactMatch("date_of_birth"),
        cl.ExactMatch("postcode").configure(term_frequency_adjustments=True),
        cl.ExactMatch("unique_id"), 
        cl.ExactMatch("state"),  
        cl.LevenshteinAtThresholds("address_1", [2, 5, 10]),
    ],
    retain_intermediate_calculation_columns=True,
)

# %%
#Initialize the Linker
db_api = DuckDBAPI()
linker = Linker(df, settings, db_api=db_api)

# %%
#  Train the Splink model to u and m parameter for the model
deterministic_rules = [
    "l.surname = r.surname AND l.postcode = r.postcode AND levenshtein(l.given_name, r.given_name) <= 1",
    "l.unique_id = r.unique_id",
]
linker.training.estimate_probability_two_random_records_match(deterministic_rules, recall=0.8)
linker.training.estimate_u_using_random_sampling(max_pairs=1e6, seed=5)


linker.training.estimate_parameters_using_expectation_maximisation(
    block_on("surname")
)
linker.training.estimate_parameters_using_expectation_maximisation(
    block_on("postcode")
)
# Out:
# Probability two random records match is estimated to be  4.75e-05.
# This means that amongst all possible pairwise record comparisons, one in 21,031.58 are expected to match.  With 499,500 total possible comparisons, we expect a total of around 23.75 matching pairs
# You are using the default value for `max_pairs`, which may be too small and thus lead to inaccurate estimates for your model's u-parameters. Consider increasing to 1e8 or 1e9, which will result in more accurate estimates, but with a longer run time.
# ----- Estimating u probabilities using random sampling -----
# u probability not trained for unique_id - Exact match on unique_id (comparison vector value: 1). This usually means the comparison level was never observed in the training data.
#
# Estimated u probabilities using random sampling
#
# Your model is not yet fully trained. Missing estimates for:
#     - given_name (no m values are trained).
#     - surname (no m values are trained).
#     - date_of_birth (no m values are trained).
#     - postcode (no m values are trained).
#     - unique_id (some u values are not trained, no m values are trained).
#     - state (no m values are trained).
#     - address_1 (no m values are trained).
#
# ----- Starting EM training session -----
#
# Estimating the m probabilities of the model by blocking on:
# l."surname" = r."surname"
#
# Parameter estimates will be made for the following comparison(s):
#     - given_name
#     - date_of_birth
#     - postcode
#     - unique_id
#     - state
#     - address_1
#
# Parameter estimates cannot be made for the following comparison(s) since they are used in the blocking rules:
#     - surname
#
# WARNING:
# Level Exact match on unique_id on comparison unique_id not observed in dataset, unable to train m value
#
# Iteration 1: Largest change in params was 0.95 in the m_probability of unique_id, level `All other comparisons`
# Iteration 2: Largest change in params was 0.0092 in the m_probability of address_1, level `Levenshtein distance of address_1 <= 10`
# Iteration 3: Largest change in params was -0.000182 in the m_probability of postcode, level `Exact match on postcode`
# Iteration 4: Largest change in params was -8.63e-06 in the m_probability of date_of_birth, level `Exact match on date_of_birth`
#
# EM converged after 4 iterations
# m probability not trained for unique_id - Exact match on unique_id (comparison vector value: 1). This usually means the comparison level was never observed in the training data.
#
# Your model is not yet fully trained. Missing estimates for:
#     - surname (no m values are trained).
#     - unique_id (some u values are not trained, some m values are not trained).
#
# ----- Starting EM training session -----
#
# Estimating the m probabilities of the model by blocking on:
# l."postcode" = r."postcode"
#
# Parameter estimates will be made for the following comparison(s):
#     - given_name
#     - surname
#     - date_of_birth
#     - unique_id
#     - state
#     - address_1
#
# Parameter estimates cannot be made for the following comparison(s) since they are used in the blocking rules:
#     - postcode
#
# WARNING:
# Level Exact match on unique_id on comparison unique_id not observed in dataset, unable to train m value
#
# Iteration 1: Largest change in params was -0.95 in the m_probability of unique_id, level `Exact match on unique_id`
# Iteration 2: Largest change in params was 0.0268 in the m_probability of address_1, level `Levenshtein distance of address_1 <= 5`
# Iteration 3: Largest change in params was 0.000363 in the m_probability of date_of_birth, level `Exact match on date_of_birth`
# Iteration 4: Largest change in params was -2.62e-05 in the m_probability of date_of_birth, level `All other comparisons`
#
# EM converged after 4 iterations
# m probability not trained for unique_id - Exact match on unique_id (comparison vector value: 1). This usually means the comparison level was never observed in the training data.
#
# Your model is not yet fully trained. Missing estimates for:
#     - unique_id (some u values are not trained, some m values are not trained).
# <EMTrainingSession, blocking on l."postcode" = r."postcode", deactivating comparisons postcode>

# %%
# Run predictions and visuallising predictions with waterfall chart 
df_predictions = linker.inference.predict(threshold_match_probability=0.9)

records_to_view = df_predictions.as_record_dict(limit=5)
linker.visualisations.waterfall_chart(records_to_view, filter_nulls=False)
# Out:
# Blocking time: 0.02 seconds
# Predict time: 0.25 seconds
#
#  -- WARNING --
# You have called predict(), but there are some parameter estimates which have neither been estimated or specified in your settings dictionary.  To produce predictions the following untrained trained parameters will use default values.
# Comparison: 'unique_id':
#     m values not fully trained
# Comparison: 'unique_id':
#     u values not fully trained
# alt.LayerChart(...)

# %%
#Cluster duplicates 
clusters = linker.clustering.cluster_pairwise_predictions_at_threshold(
    df_predictions, threshold_match_probability=0.9
)

#Save deduplicated results to datafream
df_clusters = clusters.as_pandas_dataframe()
df_clusters
# Out:
# Completed iteration 1, num representatives needing updating: 0
#      cluster_id given_name     surname  street_number           address_1  \
# 0       7364009    lachlan       berry           69.0       giblin street
# 1       2635962     deakin  sondergeld           48.0   goldfinch circuit
# 2       2025650     darcie      turtur           10.0      blacket street
# 3       7661096      abbey         fit           13.0    kosciusko avenue
# 4       2790666   isabella      lodder          156.0    messenger street
# ..          ...        ...         ...            ...                 ...
# 995     9162672       None     hefford            1.0  armstrong crescent
# 996     9162672       None     cogzell            1.0  armstrong crescent
# 997     6794161       None        durr           11.0   cochrane crescent
# 998     9128171     nacoya        lowe          381.0   sherbrooke street
# 999     9128171     nacoya        lowe          381.0   sherbropke street
#
#               address_2         suburb  postcode state  date_of_birth  \
# 0             killarney        bittern      4814   qld     19990219.0
# 1               kooltuo     canterbury      2776   vic     19600210.0
# 2                eureka  beverly hills      2263   nsw            NaN
# 3     the wharf complex           yass      2594   nsw     19870510.0
# 4    tongbong sanctuary      bayswater      4870   vic     19650714.0
# ..                  ...            ...       ...   ...            ...
# 995                None       payneham      5502   vic     19440805.0
# 996            cromdale       payneham      5502   vic     19440905.0
# 997         the rookery    south perth      2795    wa     19300521.0
# 998         bright view        pimlico      2261   qld     19050204.0
# 999        brigh t view        pimlico      2621   qld     19050204.0
#
#      unique_id
# 0      7364009
# 1      2635962
# 2      2025650
# 3      7661096
# 4      2790666
# ..         ...
# 995    9162672
# 996    9162672
# 997    6794611
# 998    9128171
# 999    9128171
#
# [1000 rows x 11 columns]

# %%
#sorting clusterd datafream with cluster_id
df_clusters_sorted = df_clusters.sort_values(by='cluster_id', ascending=True)
df_clusters_sorted.head(40)
# Out:
#      cluster_id  given_name      surname  street_number  \
# 959     1023877     michael        belci            1.0
# 958     1023877     michael        belci            1.0
# 845     1025941   evangelia         None         3335.0
# 842     1025941   evangelia         None            4.0
# 765     1030443       jacob     simmonds           54.0
# 754     1030443       jacob     simmonds           54.0
# 178     1041588       james      girdler           11.0
# 263     1041588       james      girdler           11.0
# 180     1052176     caitlin       bishop          186.0
# 629     1052176      hollie       bishop          186.0
# 194     1057415       jacob        walls           61.0
# 337     1057415       jacob        walls           61.0
# 121     1063069   alexandra  mabokmarial            7.0
# 165     1063069       caleb  mabokmarial            7.0
# 516     1066923       reeve        mileq            2.0
# 537     1066923       reeve     quilliam            2.0
# 700     1086126     madalyn      pries t            2.0
# 674     1086126     madalyn       priest            2.0
# 307     1107619      emiily      prieaux          102.0
# 61      1107619    nicholas     prideaux            9.0
# 575     1108438      tahlua     holdwnby           60.0
# 681     1108438      tahlia     holdenby           60.0
# 973     1111504    nicholas         toso            NaN
# 976     1111504    nicholas         toso           14.0
# 719     1125609       blade      charman           30.0
# 448     1125609     charman        blade           24.0
# 834     1133078      robert         None            9.0
# 41      1133078      robert       ranson            9.0
# 131     1155058     jessica   ballantyne            8.0
# 308     1155058  ballantyne      jessica            8.0
# 478     1158377    fenwic k      william            NaN
# 816     1158377     william       headon           33.0
# 491     1173489       chloe    whetstone           59.0
# 71      1173489       chloe    whetstone           59.0
# 176     1194789       ethan         rosa           24.0
# 836     1194789       ethan         None           24.0
# 384     1197846       jamie      meixner            7.0
# 242     1197846       jamie      meixner            7.0
# 46      1238636    giuliana      hammill           83.0
# 418     1238636    giuliana      hammill           31.0
#
#                      address_1          address_2             suburb  \
# 959            chisholm street  carrington garden            torquay
# 958             chisholmstreet  carrington garden            torquay
# 845                  naas road          wyncliffe          gwandalan
# 842                  naas rrad         wync liffe          gwandalan
# 765               jukes street     wee wilbertree            bunbury
# 754              jukes stcreet               None            bunbury
# 178  russell drysdale crescent         rowethorpe          mansfield
# 263  russell drysdale crescent        rowet hlrpe          mansfirld
# 180           dolling crescent            clifden             tarana
# 629           dolling crescent            clifden             tarana
# 194            atherton street              indra           st kilda
# 337            atherton street              indra           st kilda
# 121            walker crescent        border park           erindale
# 165            walker crescent        border park          erinwdale
# 516            renwick lwtreet          yarra bee       barwon heads
# 537             renwick street           yarrabee       barwon heads
# 700            fitzalan street               None         paddington
# 674            fitzalan street               None         paddington
# 307               hicks street          loccnn229     bondi junction
# 61                hicks street         loccn 7229     bondi junction
# 575              kaveneys road            villa 5              nwora
# 681              kaveneys road            villa 5              nowra
# 973          carnegie crescent             moonah        mullumbimby
# 976          carnegie crescent             moonah        mullumbimby
# 719              mcvilly close           inglemer             cooran
# 448               mcvilly cose           inglemet             cooran
# 834               crease place               None           calliope
# 41                crease place               None           calliope
# 131          medworth crescent         rowethorpe            penrith
# 308          medworth crescent         rowethorpe           pen rith
# 478             madigan street          wearmouth            emerald
# 816             madigan street          wearmouth            emerald
# 491          chuculba crescent            telooma           hamilton
# 71           chuculba crescent            telooma           hamilton
# 176                edman close             browie  werrington county
# 836                edman close             browie  werrington county
# 384           hibiscus rescent     bandicootridge           atherton
# 242          hibiscus crescent    bandicoot ridge           atherton
# 46               cobby sjtteet    parish takowahl        potts point
# 418               cobby street    parish talowahl        potts point
#
#      postcode state  date_of_birth  unique_id
# 959      5085    sa     19300418.0    1023877
# 958      5085    sa     19300418.0    1023877
# 845      2060   act     19820125.0    1025941
# 842      2006   act     19820125.0    1025941
# 765      7264    wa     19580404.0    1030443
# 754      7264    wa     19580404.0    1030443
# 178      4551   tas     19420915.0    1041588
# 263      4551   tas     19420915.0    1041588
# 180      3121   nsw     19721009.0    1052176
# 629      3121   nsw     19721009.0    1052176
# 194      3149   nsw     19490530.0    1057415
# 337      3194   nsw     19490530.0    1057415
# 121      2810   vic     19361207.0    1063069
# 165      2810   vic     19361207.0    1063069
# 516      2342   nsw     19810406.0    1067923
# 537      2340   nsw     19810406.0    1066923
# 700      2031   qld     19530429.0    1086126
# 674      2031   qld     19530429.0    1086126
# 307      5011    sa     19420429.0    1107619
# 61       5011    sa     19420429.0    1107619
# 575      2530   vic     19200814.0    1108438
# 681      2530   vic     19200814.0    1108438
# 973      5109    wa     19710120.0    1111504
# 976      5109    wa     19710120.0    1111504
# 719      4211   nsw     19980531.0    1125609
# 448      4211   nsw     19980531.0    1125609
# 834      4053   vic     19600702.0    1133078
# 41       4053   vic     19600702.0    1133078
# 131      4213   nsw     19931103.0    1155058
# 308      4213   nsw            NaN    1155058
# 478      2577   nsw     19540307.0    1158377
# 816      2577   nsw     19540307.0    1158377
# 491      3028   vic     19910803.0    1173489
# 71       3000   vic     19910803.0    1173489
# 176      5048   vic     19320829.0    1194789
# 836      5048   vic     19320829.0    1194789
# 384      4109   nsw     19670124.0    1197846
# 242      4109   nsw     19670124.0    1197846
# 46       3736   nsw     19941108.0    1238636
# 418      3763   nsw     19941108.0    1238636
